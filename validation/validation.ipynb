# %%
from subgrounds import Subgrounds

# %%
SUBGRAPH_API_URL = "https://api.thegraph.com/subgraphs/name/papercliplabs/compound-v3"

# %%
sg = Subgrounds()

comp_v3 = sg.load_subgraph(SUBGRAPH_API_URL)

# %%
markets = comp_v3.Query.markets()

sg.query_df([markets.accounting])
# Out:
#                         markets_accounting_id  \
# 0  0xa17581a9e3356d9a858b789d68b4d866e593ae94
# 1  0xc3d688b66703497daa19211eedff47f25384cdc3
#
#                  markets_accounting_market_id  \
# 0  0xa17581a9e3356d9a858b789d68b4d866e593ae94
# 1  0xc3d688b66703497daa19211eedff47f25384cdc3
#
#    markets_accounting_lastAccountingUpdatedBlockNumber  \
# 0                                           18278948
# 1                                           18282752
#
#    markets_accounting_baseSupplyIndex  markets_accounting_baseBorrowIndex  \
# 0                    1011699278116959                    1027689065784865
# 1                    1030192464182361                    1045392050949556
#
#    markets_accounting_trackingSupplyIndex  \
# 0                         314336202211541
# 1                             31478790579
#
#    markets_accounting_trackingBorrowIndex  markets_accounting_lastAccrualTime  \
# 0                                       0                          1696444139
# 1                            987460277575                          1696490087
#
#   markets_accounting_totalBasePrincipalSupply  \
# 0                     39898363810373624064829
# 1                             328711958716263
#
#   markets_accounting_totalBasePrincipalBorrow  ...  \
# 0                     24734872873469427949381  ...
# 1                             291959057778698  ...
#
#   markets_accounting_totalBaseBorrowUsd  \
# 0                          4.164629e+07
# 1                          3.052032e+08
#
#   markets_accounting_baseReserveBalanceUsd  \
# 0                             1.096596e+06
# 1                             3.139569e+06
#
#   markets_accounting_collateralBalanceUsd  \
# 0                            5.893292e+07
# 1                            6.100603e+08
#
#    markets_accounting_collateralReservesBalanceUsd  \
# 0                                              0.0
# 1                                              0.0
#
#    markets_accounting_totalReserveBalanceUsd  \
# 0                               1.096596e+06
# 1                               3.139569e+06
#
#    markets_accounting_rewardSupplyApr  markets_accounting_rewardBorrowApr  \
# 0                            0.016866                            0.000000
# 1                            0.012090                            0.019877
#
#    markets_accounting_netSupplyApr  markets_accounting_netBorrowApr  \
# 0                         0.034740                         0.033246
# 1                         0.042734                         0.020136
#
#    markets_accounting_collateralization
# 0                              1.587944
# 1                              1.109514
#
# [2 rows x 27 columns]
